# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

w_C = Counter(int_words)

f = {word: count/len(int_words) for word, count in w_C.items()}
p_drop = {word: 1 - np.sqrt(1e-5/f[word]) for word in w_C}

train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    targets = set(words[start:idx] + words[idx + 1:stop + 1])
    
    return list(targets)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6241 0.0812 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6228 0.0814 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4916 0.0813 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5914 0.0814 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5295 0.0820 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5403 0.0817 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5677 0.0814 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5567 0.0789 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4665 0.0813 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4244 0.0813 sec/batch
# Nearest to also: viva, harmonious, rearrange, libel, obviously, fundamentalists, recht, year,
# Nearest to about: pir, loud, aligning, hughie, endemic, spoilage, norwood, siro,
# Nearest to the: melkite, dga, broadbent, photophone, schaefer, transportation, elicit, different,
# Nearest to most: redesigns, online, barter, lineage, aglaulus, dimensions, ocd, supervisor,
# Nearest to eight: depiction, centimes, sirach, online, novel, franz, bocce, communist,
# Nearest to world: enlarging, upto, porritt, niall, compagnie, blogger, despatch, melanippe,
# Nearest to used: maintained, euwe, adolescence, elfland, marino, coles, skie, shifts,
# Nearest to if: semele, mlm, cancels, saarland, prophetically, pieced, transsexualism, intuitionism,
# Nearest to event: cleric, peninsula, antioch, lizard, kenyatta, mails, badajoz, factorizations,
# Nearest to road: mathieu, downer, conciliation, kushan, subjectively, lionel, gaians, tyburn,
# Nearest to versions: itu, bilingual, joke, moloch, brun, pardubice, rally, springing,
# Nearest to egypt: mctell, immersed, own, wildcard, urinal, nuclei, franjo, axumite,
# Nearest to assembly: sabotage, federation, criticizing, cargo, imo, boarded, churchmen, abject,
# Nearest to active: adopter, bohr, handicap, exodus, kapitan, vulpes, pilger, cheshire,
# Nearest to square: zonker, clarinet, carvey, schiaparelli, democratic, implantable, scatter, pi,
# Nearest to scale: slant, materialistic, pappas, lads, crossfire, duos, vito, maseru,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4832 0.0824 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3937 0.0818 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3299 0.0810 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2350 0.0814 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1631 0.0815 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1484 0.0814 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0882 0.0814 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0620 0.0817 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0073 0.0834 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9903 0.0819 sec/batch
# Nearest to also: obviously, viva, harmonious, year, rearrange, load, fundamentalists, libel,
# Nearest to about: loud, moving, pir, countries, hughie, aligning, endemic, norwood,
# Nearest to the: melkite, fail, wide, different, claw, scope, you, lacks,
# Nearest to most: redesigns, online, dimensions, lineage, problems, deadly, barter, rapid,
# Nearest to eight: depiction, took, communist, centimes, online, franz, novel, f,
# Nearest to world: planning, enlarging, although, anyone, greater, upto, domestic, disabled,
# Nearest to used: maintained, adolescence, jazz, shifts, fill, replies, driving, hugely,
# Nearest to if: maintained, divisions, value, mlm, semele, infiltrate, saarland, shipping,
# Nearest to event: cleric, kenyatta, factorizations, lizard, peninsula, hostilities, antioch, rotor,
# Nearest to road: mathieu, conciliation, downer, subjectively, bit, achieving, kushan, outcrops,
# Nearest to versions: bilingual, joke, itu, been, begin, rally, moloch, avars,
# Nearest to egypt: own, mctell, wildcard, immersed, urinal, nuclei, mph, crowd,
# Nearest to assembly: federation, sabotage, criticizing, cargo, boarded, timed, remaining, substitute,
# Nearest to active: adopter, crisis, bohr, handicap, exodus, percentage, ton, analysis,
# Nearest to square: democratic, clarinet, zonker, union, carvey, pi, schiaparelli, scatter,
# Nearest to scale: materialistic, vito, pappas, duos, slant, usps, are, locks,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9282 0.0834 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8944 0.0830 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8818 0.0829 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8582 0.0836 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7881 0.0837 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8015 0.0832 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7942 0.0836 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7889 0.0828 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7900 0.0839 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7752 0.0843 sec/batch
# Nearest to also: obviously, viva, harmonious, rearrange, fundamentalists, cancellation, libel, brittle,
# Nearest to about: pir, loud, aligning, moving, countries, hughie, endemic, brittle,
# Nearest to the: melkite, lacks, eureka, fail, claw, photophone, elicit, casualties,
# Nearest to most: redesigns, dimensions, online, jupiter, lineage, raster, ratified, supervisor,
# Nearest to eight: depiction, franz, centimes, took, communist, lorenzo, maurice, extremes,
# Nearest to world: planning, enlarging, disabled, although, maison, compagnie, upto, blogger,
# Nearest to used: maintained, adolescence, fill, shifts, jazz, euwe, elfland, geometer,
# Nearest to if: value, semele, divisions, pieced, mlm, saarland, intuitionism, maintained,
# Nearest to event: cleric, factorizations, kenyatta, peninsula, lizard, mails, antioch, website,
# Nearest to road: mathieu, conciliation, downer, bit, subjectively, achieving, toured, kushan,
# Nearest to versions: joke, bilingual, itu, begin, rally, brun, moloch, relics,
# Nearest to egypt: own, mctell, immersed, wildcard, nuclei, mph, crowd, sparsely,
# Nearest to assembly: sabotage, federation, criticizing, cargo, rhymes, abject, representative, boarded,
# Nearest to active: bohr, exodus, adopter, crisis, handicap, ton, percentage, pilger,
# Nearest to square: clarinet, zonker, democratic, pi, carvey, union, scatter, fistful,
# Nearest to scale: materialistic, pappas, vito, slant, duos, crossfire, locks, reflections,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7873 0.0851 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7435 0.0856 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7108 0.0865 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7267 0.0884 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7632 0.0882 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7331 0.0880 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7197 0.0894 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7124 0.0899 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7184 0.0878 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6186 0.0922 sec/batch
# Nearest to also: harmonious, rearrange, viva, obviously, fundamentalists, cancellation, renew, supplant,
# Nearest to about: pir, gaston, aligning, apostates, endemic, nth, plea, loud,
# Nearest to the: melkite, gained, photophone, eureka, derail, elicit, casualties, lacks,
# Nearest to most: redesigns, dimensions, online, jupiter, raster, barter, columbia, lineage,
# Nearest to eight: depiction, franz, johann, lorenzo, nobel, centimes, took, erich,
# Nearest to world: planning, disabled, enlarging, blogger, compagnie, puzzle, domestic, upto,
# Nearest to used: maintained, fill, adolescence, elfland, shifts, jazz, euwe, supercharged,
# Nearest to if: value, intuitionism, pieced, mlm, semele, saarland, cancels, bubble,
# Nearest to event: cleric, factorizations, lizard, mails, kenyatta, peninsula, antioch, leben,
# Nearest to road: mathieu, conciliation, downer, bit, kushan, subjectively, achieving, toured,
# Nearest to versions: joke, bilingual, rally, moloch, brun, healthier, springing, stupa,
# Nearest to egypt: immersed, wildcard, mctell, aryabhata, own, nuclei, axumite, urinal,
# Nearest to assembly: sabotage, federation, abject, criticizing, representative, rhymes, boarded, atkins,
# Nearest to active: exodus, handicap, adopter, bohr, crisis, pilger, ton, percentage,
# Nearest to square: clarinet, zonker, democratic, pi, carvey, riebeeck, cleves, scatter,
# Nearest to scale: materialistic, pappas, slant, crossfire, vito, decompositions, are, locks,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6653 0.0924 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6724 0.0934 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6062 0.0929 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6183 0.0924 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6572 0.0934 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6469 0.0924 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6018 0.0676 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5532 0.0933 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5198 0.0970 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5342 0.0957 sec/batch
# Nearest to also: rearrange, harmonious, obviously, viva, fundamentalists, supplant, cancellation, topspinner,
# Nearest to about: pir, gaston, latch, exquisite, fatimid, apostates, aligning, assassinations,
# Nearest to the: claw, eureka, melkite, gained, hecate, freemen, lacks, photophone,
# Nearest to most: redesigns, dimensions, barter, jupiter, lineage, online, raster, aglaulus,
# Nearest to eight: franz, nobel, johann, erich, depiction, lorenzo, maurice, statesman,
# Nearest to world: planning, disabled, blogger, enlarging, compagnie, domestic, lillard, melanippe,
# Nearest to used: maintained, elfland, fill, supercharged, shifts, adolescence, nu, color,
# Nearest to if: value, intuitionism, mlm, pieced, values, semele, bubble, cancels,
# Nearest to event: cleric, factorizations, lizard, mails, badajoz, kenyatta, setae, enrico,
# Nearest to road: mathieu, conciliation, downer, kushan, bit, subjectively, achieving, triples,
# Nearest to versions: joke, bilingual, brun, subsidiaries, moloch, ftp, culmination, stupa,
# Nearest to egypt: immersed, mctell, aryabhata, wildcard, axumite, urinal, crowd, own,
# Nearest to assembly: federation, sabotage, abject, atkins, criticizing, representative, boarded, rhymes,
# Nearest to active: exodus, handicap, crisis, adopter, pilger, bohr, percentage, shinto,
# Nearest to square: clarinet, zonker, scatter, implantable, riebeeck, pi, cleves, fistful,
# Nearest to scale: pappas, materialistic, slant, crossfire, are, decompositions, invariant, satsuki,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4897 0.0987 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4750 0.0945 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4418 0.0921 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4895 0.0940 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4679 0.0953 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4628 0.0939 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4606 0.0946 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3757 0.0942 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4206 0.0955 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4251 0.0929 sec/batch
# Nearest to also: rearrange, harmonious, obviously, supplant, brittle, fundamentalists, additionally, topspinner,
# Nearest to about: pir, fatimid, digraphs, countries, apostates, siro, gaston, brittle,
# Nearest to the: claw, eureka, melkite, nationalities, gained, hecate, ignores, lacks,
# Nearest to most: redesigns, dimensions, jupiter, barter, aglaulus, lineage, columbia, nac,
# Nearest to eight: franz, depiction, lorenzo, erich, nobel, centimes, physiologist, alcide,
# Nearest to world: planning, blogger, domestic, disabled, compagnie, enlarging, lillard, melanippe,
# Nearest to used: shifts, maintained, supercharged, fill, elfland, color, verbal, nu,
# Nearest to if: value, intuitionism, values, bubble, mlm, pieced, cantonese, cancels,
# Nearest to event: cleric, factorizations, lizard, badajoz, enrico, large, mails, fright,
# Nearest to road: mathieu, conciliation, downer, covington, kushan, cassian, bit, suburbs,
# Nearest to versions: joke, bilingual, concurrency, ftp, brun, moloch, culmination, stupa,
# Nearest to egypt: immersed, aryabhata, axumite, mctell, wildcard, urinal, own, franjo,
# Nearest to assembly: sabotage, federation, abject, representative, atkins, redress, inasmuch, churchmen,
# Nearest to active: exodus, adopter, crisis, handicap, percentage, pilger, bohr, ton,
# Nearest to square: clarinet, riebeeck, zonker, scatter, pi, cdp, cleves, meters,
# Nearest to scale: materialistic, pappas, slant, crossfire, are, decompositions, cooperstown, invariant,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4407 0.0941 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4058 0.0939 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4192 0.0914 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4218 0.0919 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3946 0.0915 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4311 0.0910 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3585 0.0906 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3751 0.0882 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4244 0.0903 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3784 0.0890 sec/batch
# Nearest to also: rearrange, harmonious, obviously, viva, supplant, brittle, libel, propylaea,
# Nearest to about: pir, apostates, fatimid, brittle, digraphs, latch, ludwik, siro,
# Nearest to the: claw, identity, freemen, completeness, eureka, confronted, varphi, melkite,
# Nearest to most: redesigns, dimensions, habitat, barter, nac, aglaulus, and, rapid,
# Nearest to eight: lorenzo, franz, physiologist, centimes, depiction, erich, nobel, dazed,
# Nearest to world: planning, blogger, compagnie, domestic, disabled, enlarging, copra, rede,
# Nearest to used: maintained, fill, elfland, shifts, supercharged, color, cheddar, adolescence,
# Nearest to if: value, intuitionism, values, cancels, pieced, appendage, mlm, ideal,
# Nearest to event: cleric, factorizations, lizard, amounting, inline, fright, badajoz, enrico,
# Nearest to road: mathieu, conciliation, downer, covington, cassian, kushan, part, suburbs,
# Nearest to versions: joke, ftp, concurrency, brun, bilingual, subsidiaries, stupa, programs,
# Nearest to egypt: axumite, immersed, greeks, urinal, aryabhata, mctell, ndez, sparsely,
# Nearest to assembly: federation, sabotage, abject, representative, redress, criticizing, approved, atkins,
# Nearest to active: adopter, handicap, percentage, bohr, exodus, pilger, crisis, upc,
# Nearest to square: clarinet, riebeeck, zonker, pi, cdp, implantable, scatter, meters,
# Nearest to scale: materialistic, slant, pappas, crossfire, are, invariant, cooperstown, decompositions,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3523 0.0891 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3783 0.0875 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3335 0.0871 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3632 0.0862 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4166 0.0850 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3771 0.0861 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4028 0.0843 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3930 0.0846 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3297 0.0843 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3648 0.0834 sec/batch
# Nearest to also: rearrange, harmonious, obviously, supplant, libel, brittle, viva, viability,
# Nearest to about: pir, apostates, fatimid, brittle, assassinations, latch, digraphs, countries,
# Nearest to the: united, varphi, identity, claw, extending, confronted, stream, freemen,
# Nearest to most: redesigns, rapid, and, dimensions, habitat, barter, nac, lineage,
# Nearest to eight: centimes, erich, zero, lorenzo, physiologist, depiction, dazed, franz,
# Nearest to world: planning, domestic, blogger, compagnie, disabled, copra, reinterpreting, cagayan,
# Nearest to used: fill, maintained, elfland, nu, commonly, shifts, cheddar, adolescence,
# Nearest to if: value, intuitionism, values, cancels, appendage, pieced, mlm, opinion,
# Nearest to event: cleric, factorizations, fright, enrico, amounting, lizard, inline, infraclass,
# Nearest to road: mathieu, conciliation, covington, downer, cassian, part, suburbs, kushan,
# Nearest to versions: ftp, joke, concurrency, gnu, programs, os, bilingual, scripting,
# Nearest to egypt: axumite, immersed, greeks, ndez, aryabhata, urinal, mctell, clergyman,
# Nearest to assembly: federation, representative, sabotage, abject, redress, criticizing, approved, atkins,
# Nearest to active: adopter, handicap, exodus, pilger, percentage, crisis, worldwide, bohr,
# Nearest to square: clarinet, riebeeck, cdp, zonker, pi, meters, scatter, implantable,
# Nearest to scale: materialistic, slant, crossfire, pappas, nearest, decompositions, cooperstown, are,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3516 0.0847 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3152 0.0834 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3551 0.0825 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3731 0.0819 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3977 0.0825 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3011 0.0827 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3264 0.0828 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3363 0.0827 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2244 0.0819 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2936 0.0825 sec/batch
# Nearest to also: rearrange, harmonious, obviously, supplant, breakfast, viva, niger, renew,
# Nearest to about: pir, apostates, fatimid, latch, digraphs, brittle, endemic, assassinations,
# Nearest to the: varphi, invigorating, united, ldf, episcopalians, extending, subdiscipline, gained,
# Nearest to most: redesigns, barter, rapid, habitat, and, nac, neman, dimensions,
# Nearest to eight: physiologist, erich, franz, lorenzo, four, three, zero, centimes,
# Nearest to world: planning, domestic, blogger, copra, compagnie, reinterpreting, although, rede,
# Nearest to used: fill, elfland, commonly, maintained, nu, color, supercharged, aktion,
# Nearest to if: value, intuitionism, cancels, values, appendage, coordinate, pieced, mlm,
# Nearest to event: cleric, fright, lizard, amounting, factorizations, enrico, insurers, inline,
# Nearest to road: mathieu, covington, downer, conciliation, cassian, outcrops, triples, gskola,
# Nearest to versions: ftp, joke, concurrency, gnu, os, scripting, programs, collection,
# Nearest to egypt: axumite, immersed, greeks, sparsely, ndez, ferrer, dualistic, monarchic,
# Nearest to assembly: federation, representative, abject, sabotage, redress, criticizing, elected, approved,
# Nearest to active: handicap, adopter, exodus, pilger, crisis, worldwide, percentage, upc,
# Nearest to square: meters, clarinet, riebeeck, cdp, pi, scatter, zonker, implantable,
# Nearest to scale: materialistic, slant, pappas, crossfire, decompositions, cooperstown, nearest, locks,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3140 0.0836 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3012 0.0825 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3288 0.0369 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2553 0.0812 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2259 0.0816 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2354 0.0819 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1985 0.0818 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2309 0.0823 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2119 0.0817 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1703 0.0823 sec/batch
# Nearest to also: rearrange, harmonious, propylaea, obviously, breakfast, batou, niger, coolers,
# Nearest to about: pir, fatimid, apostates, digraphs, brittle, assassinations, iotation, europe,
# Nearest to the: varphi, invigorating, extending, ldf, episcopalians, united, longinus, fringing,
# Nearest to most: redesigns, barter, rapid, dimensions, neman, and, columbia, lineage,
# Nearest to eight: physiologist, three, centimes, four, zero, five, one, lorenzo,
# Nearest to world: planning, domestic, copra, blogger, rede, compagnie, cagayan, although,
# Nearest to used: fill, elfland, commonly, maintained, nu, aktion, jazz, shifts,
# Nearest to if: value, intuitionism, cancels, values, appendage, saarland, mlm, coordinate,
# Nearest to event: cleric, fright, badajoz, lizard, amounting, enrico, insurers, inline,
# Nearest to road: mathieu, covington, downer, cassian, conciliation, triples, outcrops, part,
# Nearest to versions: ftp, os, joke, gnu, scripting, programs, concurrency, bilingual,
# Nearest to egypt: immersed, axumite, greeks, sparsely, dualistic, ndez, clergyman, wildcard,
# Nearest to assembly: federation, abject, representative, redress, sabotage, constraint, elected, mench,
# Nearest to active: handicap, adopter, pilger, worldwide, crisis, unpaid, exodus, pedophile,
# Nearest to square: meters, riebeeck, clarinet, cdp, pi, scatter, zonker, coordinates,
# Nearest to scale: materialistic, pappas, cooperstown, crossfire, nearest, slant, ttan, decompositions,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2335 0.0829 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2349 0.0817 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2327 0.0835 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1326 0.0829 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1886 0.0823 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1782 0.0825 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1762 0.0817 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1965 0.0829 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1974 0.0829 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1781 0.0825 sec/batch
# Nearest to also: rearrange, harmonious, propylaea, obviously, brittle, coolers, virtualization, breakfast,
# Nearest to about: apostates, pir, brittle, fatimid, iotation, annual, digraphs, slime,
# Nearest to the: varphi, a, invigorating, ibex, stream, fringing, subdiscipline, extending,
# Nearest to most: redesigns, dimensions, barter, ircii, lineage, and, neman, rapid,
# Nearest to eight: four, three, zero, physiologist, five, centimes, lorenzo, one,
# Nearest to world: planning, copra, rede, blogger, domestic, despatch, compagnie, although,
# Nearest to used: fill, commonly, elfland, maintained, modern, shifts, verbal, benzodiazepine,
# Nearest to if: value, intuitionism, values, cancels, appendage, algebras, coordinate, yes,
# Nearest to event: cleric, fright, badajoz, factorizations, lizard, amounting, enrico, inline,
# Nearest to road: covington, mathieu, downer, outcrops, cassian, suburbs, conciliation, triples,
# Nearest to versions: joke, scripting, concurrency, ftp, programs, minicomputers, os, gnu,
# Nearest to egypt: immersed, axumite, greeks, sparsely, ndez, dualistic, wildcard, aryabhata,
# Nearest to assembly: abject, representative, federation, redress, elected, deputies, sabotage, mench,
# Nearest to active: adopter, handicap, crisis, pilger, worldwide, plaintiffs, upc, unpaid,
# Nearest to square: riebeeck, cdp, clarinet, meters, pi, coordinates, scatter, outer,
# Nearest to scale: materialistic, nearest, pappas, slant, cooperstown, ttan, crossfire, chinguetti,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1883 0.0832 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2155 0.0830 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1699 0.0828 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1573 0.0824 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2003 0.0822 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2051 0.0821 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2051 0.0828 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1645 0.0824 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1404 0.0821 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1791 0.0822 sec/batch
# Nearest to also: rearrange, propylaea, harmonious, obviously, coolers, denatured, virtualization, obtainable,
# Nearest to about: apostates, pir, annual, brittle, fatimid, iotation, urn, balmaceda,
# Nearest to the: varphi, invigorating, a, stream, ldf, breached, partement, fringing,
# Nearest to most: redesigns, barter, neman, ircii, dimensions, and, brahmi, lineage,
# Nearest to eight: four, three, zero, five, centimes, one, physiologist, lorenzo,
# Nearest to world: planning, copra, rede, blogger, domestic, despatch, greater, reinterpreting,
# Nearest to used: fill, commonly, elfland, maintained, jazz, modern, cues, nu,
# Nearest to if: value, intuitionism, cancels, values, appendage, yes, mlm, macrophages,
# Nearest to event: cleric, fright, inline, insurers, amounting, enrico, factorizations, badajoz,
# Nearest to road: covington, mathieu, outcrops, suburbs, downer, cassian, conciliation, triples,
# Nearest to versions: joke, scripting, concurrency, collection, proportione, minicomputers, ftp, programs,
# Nearest to egypt: immersed, axumite, greeks, sparsely, ndez, delicate, wildcard, dualistic,
# Nearest to assembly: representative, redress, abject, federation, elected, deputies, appoints, parliament,
# Nearest to active: handicap, adopter, upc, unpaid, pilger, plaintiffs, kevlar, exodus,
# Nearest to square: pi, riebeeck, clarinet, cdp, outer, meters, coordinates, implantable,
# Nearest to scale: materialistic, nearest, cooperstown, ttan, slant, chinguetti, pappas, kaiju,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1891 0.0839 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1970 0.0819 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1712 0.0825 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1919 0.0828 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1279 0.0829 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1402 0.0831 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1478 0.0825 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1490 0.0839 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1843 0.0830 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1971 0.0824 sec/batch
# Nearest to also: rearrange, propylaea, obviously, harmonious, coolers, libel, breakfast, cajuns,
# Nearest to about: apostates, pir, fatimid, assassinations, irony, annual, slime, urn,
# Nearest to the: episcopalians, a, united, of, ghor, confronted, breached, tanach,
# Nearest to most: redesigns, barter, ircii, neman, and, dimensions, lineage, brahmi,
# Nearest to eight: four, five, one, zero, three, physiologist, lorenzo, two,
# Nearest to world: planning, copra, rede, domestic, reinterpreting, blogger, compagnie, benefactors,
# Nearest to used: commonly, elfland, maintained, fill, modern, jazz, verbal, nu,
# Nearest to if: value, cancels, intuitionism, values, appendage, yes, saarland, mlm,
# Nearest to event: cleric, fright, amounting, insurers, enrico, lizard, badajoz, infraclass,
# Nearest to road: covington, mathieu, suburbs, cassian, outcrops, downer, conciliation, mccormick,
# Nearest to versions: joke, scripting, concurrency, proportione, collection, bilingual, minicomputers, gnu,
# Nearest to egypt: immersed, axumite, greeks, sparsely, ndez, wmd, delicate, aryabhata,
# Nearest to assembly: representative, redress, federation, abject, elected, deputies, appoints, criticizing,
# Nearest to active: handicap, adopter, exodus, upc, plaintiffs, pilger, reinhardt, unpaid,
# Nearest to square: riebeeck, pi, cdp, clarinet, meters, outer, coordinates, zonker,
# Nearest to scale: materialistic, nearest, ttan, slant, cooperstown, chinguetti, voltages, gillies,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2251 0.0842 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1308 0.0819 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1436 0.0822 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1582 0.0823 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0615 0.0825 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1293 0.0826 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1636 0.0826 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1467 0.0820 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1351 0.0137 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1311 0.0826 sec/batch
# Nearest to also: rearrange, propylaea, cajuns, niger, obviously, denatured, catalog, overview,
# Nearest to about: annual, apostates, pir, fatimid, aspen, assassinations, dwarf, urn,
# Nearest to the: varphi, a, zoom, united, invigorating, of, ldf, on,
# Nearest to most: barter, redesigns, and, ircii, dimensions, rapid, neman, brahmi,
# Nearest to eight: four, zero, five, three, one, centimes, physiologist, two,
# Nearest to world: planning, copra, rede, blogger, reinterpreting, domestic, benefactors, harshness,
# Nearest to used: commonly, elfland, fill, jazz, maintained, nu, aktion, modern,
# Nearest to if: value, cancels, values, intuitionism, appendage, yes, coprime, macrophages,
# Nearest to event: cleric, fright, amounting, insurers, months, enrico, infraclass, lizard,
# Nearest to road: covington, mathieu, suburbs, outcrops, cassian, downer, mccormick, triples,
# Nearest to versions: scripting, gnu, os, minicomputers, desktops, collection, concurrency, joke,
# Nearest to egypt: immersed, axumite, greeks, ndez, sparsely, delicate, wmd, dualistic,
# Nearest to assembly: federation, representative, elected, redress, deputies, abject, appoints, mench,
# Nearest to active: handicap, pilger, upc, adopter, exodus, profoundly, worldwide, kevlar,
# Nearest to square: pi, riebeeck, cdp, clarinet, meters, outer, coordinates, hovercraft,
# Nearest to scale: materialistic, nearest, ttan, voltages, interquartile, slant, interrupt, cooperstown,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0802 0.0838 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0726 0.0828 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0955 0.0823 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0575 0.0824 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0597 0.0835 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0633 0.0832 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0693 0.0820 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0882 0.0823 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1305 0.0825 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0150 0.0819 sec/batch
# Nearest to also: rearrange, denatured, propylaea, obviously, breakfast, coolers, catalog, brittle,
# Nearest to about: annual, apostates, pir, fatimid, aspen, urn, slime, dwarf,
# Nearest to the: a, of, varphi, this, zoom, with, in, as,
# Nearest to most: barter, redesigns, and, ircii, neman, dimensions, brahmi, rapid,
# Nearest to eight: four, three, five, zero, one, centimes, two, physiologist,
# Nearest to world: copra, planning, rede, harshness, sukhothai, domestic, blogger, denslow,
# Nearest to used: commonly, modern, elfland, fill, whimsical, maintained, jazz, symbols,
# Nearest to if: value, values, cancels, intuitionism, appendage, yes, algebras, macrophages,
# Nearest to event: cleric, amounting, fright, insurers, infraclass, enrico, inline, commemoration,
# Nearest to road: covington, suburbs, mathieu, cassian, outcrops, mccormick, downer, triples,
# Nearest to versions: scripting, minicomputers, os, bundled, concurrency, desktops, gnu, impeding,
# Nearest to egypt: immersed, axumite, delicate, greeks, dualistic, ndez, sparsely, wildcard,
# Nearest to assembly: elected, redress, representative, federation, deputies, abject, mench, constraint,
# Nearest to active: exodus, handicap, adopter, pilger, profoundly, upc, plaintiffs, kevlar,
# Nearest to square: pi, cdp, riebeeck, clarinet, outer, meters, coordinates, zonker,
# Nearest to scale: materialistic, ttan, nearest, slant, voltages, interrupt, interquartile, chinguetti,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0377 0.0832 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0188 0.0826 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0067 0.0822 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0663 0.0831 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0691 0.0825 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0604 0.0827 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0673 0.0821 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1083 0.0820 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0676 0.0827 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0132 0.0831 sec/batch
# Nearest to also: rearrange, propylaea, denatured, science, catalog, overview, modeled, dover,
# Nearest to about: annual, apostates, dwarf, slime, pir, aspen, brittle, yee,
# Nearest to the: a, of, as, framework, varphi, this, with, in,
# Nearest to most: redesigns, barter, and, ircii, dimensions, are, lineage, rapid,
# Nearest to eight: four, three, five, one, zero, two, physiologist, centimes,
# Nearest to world: planning, rede, copra, harshness, denslow, scientology, pulses, apl,
# Nearest to used: commonly, maintained, elfland, whimsical, cyanine, cues, jazz, fill,
# Nearest to if: value, values, cancels, intuitionism, algebras, yes, appendage, coprime,
# Nearest to event: amounting, cleric, fright, insurers, infraclass, premises, large, inline,
# Nearest to road: covington, mathieu, mccormick, outcrops, suburbs, cassian, downer, tombigbee,
# Nearest to versions: scripting, impeding, joke, bundled, collection, minicomputers, concurrency, proportione,
# Nearest to egypt: immersed, axumite, delicate, ndez, sparsely, aryabhata, wmd, greeks,
# Nearest to assembly: elected, representative, redress, federation, deputies, abject, appointed, appoints,
# Nearest to active: exodus, handicap, upc, plaintiffs, profoundly, adopter, kevlar, pilger,
# Nearest to square: pi, outer, meters, cdp, coordinates, riebeeck, clarinet, implantable,
# Nearest to scale: materialistic, voltages, ttan, slant, nearest, interquartile, most, kaiju,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0624 0.0838 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0950 0.0828 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0549 0.0828 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0817 0.0824 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0806 0.0826 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0599 0.0824 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0766 0.0823 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0707 0.0822 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0862 0.0821 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0585 0.0817 sec/batch
# Nearest to also: rearrange, propylaea, denatured, niger, fundamentalists, negligible, obviously, coolers,
# Nearest to about: apostates, annual, pir, fatimid, dwarf, slime, irony, aspen,
# Nearest to the: of, a, as, this, with, united, in, on,
# Nearest to most: redesigns, barter, ircii, and, neman, brahmi, rapid, dimensions,
# Nearest to eight: four, three, five, one, zero, two, centimes, est,
# Nearest to world: planning, rede, copra, harshness, reinterpreting, sukhothai, maoists, denslow,
# Nearest to used: commonly, maintained, whimsical, elfland, fill, jazz, cyanine, toast,
# Nearest to if: cancels, value, values, intuitionism, yes, appendage, algebras, mlm,
# Nearest to event: cleric, amounting, fright, infraclass, insurers, enrico, premises, inline,
# Nearest to road: covington, outcrops, cassian, suburbs, mathieu, mccormick, tombigbee, downer,
# Nearest to versions: scripting, gnu, os, bundled, joke, solaris, proportione, collection,
# Nearest to egypt: axumite, immersed, ndez, delicate, greeks, sparsely, hellespont, wmd,
# Nearest to assembly: elected, representative, redress, deputies, federation, abject, appoints, mench,
# Nearest to active: handicap, exodus, profoundly, upc, kevlar, plaintiffs, adopter, bhra,
# Nearest to square: pi, outer, cdp, riebeeck, clarinet, meters, coordinates, implantable,
# Nearest to scale: materialistic, ttan, nearest, slant, kaiju, interquartile, chinguetti, voltages,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0632 0.0838 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0198 0.0825 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0673 0.0820 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0582 0.0834 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0845 0.0828 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1107 0.0824 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1198 0.0825 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0347 0.0827 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0345 0.0817 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0467 0.0821 sec/batch
# Nearest to also: rearrange, denatured, catalog, obviously, propylaea, in, fundamentalists, negligible,
# Nearest to about: annual, apostates, fatimid, irony, pir, urn, slime, brittle,
# Nearest to the: a, of, on, in, varphi, as, zoom, this,
# Nearest to most: barter, and, redesigns, ircii, rapid, neman, dimensions, brahmi,
# Nearest to eight: four, three, five, zero, one, two, centimes, est,
# Nearest to world: planning, copra, rede, sukhothai, reinterpreting, harshness, armigerous, blogger,
# Nearest to used: commonly, whimsical, elfland, maintained, jazz, nu, fill, cyanine,
# Nearest to if: values, cancels, value, intuitionism, yes, algebras, converges, coprime,
# Nearest to event: cleric, amounting, fright, infraclass, insurers, enrico, commemoration, months,
# Nearest to road: covington, mccormick, cassian, outcrops, tombigbee, suburbs, mathieu, downer,
# Nearest to versions: scripting, joke, gnu, solaris, collection, os, proportione, phishing,
# Nearest to egypt: axumite, immersed, delicate, ndez, aryabhata, hellespont, wmd, sparsely,
# Nearest to assembly: elected, deputies, representative, federation, abject, redress, mench, appointing,
# Nearest to active: handicap, exodus, plaintiffs, kevlar, bhra, upc, profoundly, adopter,
# Nearest to square: cdp, outer, riebeeck, pi, clarinet, meters, coordinates, implantable,
# Nearest to scale: materialistic, ttan, slant, most, chinguetti, interquartile, nearest, voltages,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0074 0.0834 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0368 0.0833 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0390 0.0813 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0295 0.0818 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0913 0.0813 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0319 0.0719 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0340 0.0814 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0006 0.0818 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0128 0.0821 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9773 0.0819 sec/batch
# Nearest to also: denatured, rearrange, in, catalog, propylaea, obviously, negligible, modeled,
# Nearest to about: apostates, fatimid, annual, dwarf, slime, irony, urn, aspen,
# Nearest to the: a, of, this, as, in, with, on, varphi,
# Nearest to most: and, barter, redesigns, ircii, dimensions, are, variety, brahmi,
# Nearest to eight: four, one, three, five, zero, two, six, centimes,
# Nearest to world: copra, planning, rede, sukhothai, armigerous, reinterpreting, harshness, carbondale,
# Nearest to used: commonly, whimsical, use, syngas, elfland, cyanine, cues, nu,
# Nearest to if: cancels, values, value, intuitionism, yes, macrophages, converges, appendage,
# Nearest to event: cleric, amounting, fright, infraclass, insurers, enrico, months, commemoration,
# Nearest to road: cassian, covington, outcrops, mccormick, downer, tombigbee, triples, mathieu,
# Nearest to versions: scripting, os, solaris, gnu, bundled, minicomputers, most, programs,
# Nearest to egypt: immersed, axumite, delicate, ndez, aryabhata, hellespont, platonic, dualistic,
# Nearest to assembly: elected, deputies, federation, representative, abject, mench, emendations, appointing,
# Nearest to active: exodus, handicap, upc, pilger, profoundly, bhra, plaintiffs, brasilia,
# Nearest to square: outer, cdp, riebeeck, clarinet, pi, meters, hovercraft, coordinates,
# Nearest to scale: materialistic, ttan, nearest, most, interquartile, chinguetti, slant, voltages,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9879 0.0831 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9316 0.0828 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0310 0.0811 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0428 0.0826 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0016 0.0811 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0180 0.0822 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9039 0.0826 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9373 0.0824 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9480 0.0827 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9813 0.0827 sec/batch
# Nearest to also: in, denatured, rearrange, catalog, modeled, of, negligible, obviously,
# Nearest to about: annual, apostates, dwarf, brittle, fatimid, slime, gobi, urn,
# Nearest to the: a, of, in, with, as, this, on, second,
# Nearest to most: and, ircii, barter, are, variety, dimensions, redesigns, rapid,
# Nearest to eight: four, three, zero, one, five, two, six, km,
# Nearest to world: copra, rede, planning, sukhothai, harshness, seaweed, worldwide, reinterpreting,
# Nearest to used: commonly, use, whimsical, syngas, phenyl, cyanine, solely, toast,
# Nearest to if: cancels, values, value, intuitionism, yes, coprime, converges, appendage,
# Nearest to event: cleric, amounting, infraclass, fright, insurers, enrico, commemoration, months,
# Nearest to road: outcrops, cassian, covington, mccormick, tombigbee, suburbs, downer, triples,
# Nearest to versions: bundled, scripting, solaris, os, subsidiaries, minicomputers, impeding, joke,
# Nearest to egypt: immersed, axumite, delicate, aryabhata, ndez, hellespont, dualistic, wildcard,
# Nearest to assembly: elected, deputies, abject, federation, representative, mench, redress, appoints,
# Nearest to active: exodus, handicap, upc, adopter, kevlar, karine, pilger, bhra,
# Nearest to square: outer, cdp, riebeeck, clarinet, pi, meters, coordinates, memel,
# Nearest to scale: materialistic, ttan, interquartile, chinguetti, slant, stimulated, kaiju, most,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0100 0.0837 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0171 0.0834 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9482 0.0829 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0375 0.0827 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0209 0.0825 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9491 0.0831 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0067 0.0840 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9853 0.0831 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9523 0.0837 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0178 0.0819 sec/batch
# Nearest to also: in, denatured, rearrange, modeled, catalog, of, fundamentalists, cajuns,
# Nearest to about: apostates, annual, news, dwarf, irony, fatimid, pir, urn,
# Nearest to the: a, of, in, on, with, as, this, second,
# Nearest to most: and, ircii, variety, barter, dimensions, redesigns, are, some,
# Nearest to eight: four, one, three, zero, five, two, nine, six,
# Nearest to world: copra, rede, planning, sukhothai, reinterpreting, armigerous, carbondale, maoists,
# Nearest to used: commonly, whimsical, use, cyanine, syngas, phenyl, solely, toast,
# Nearest to if: cancels, values, value, intuitionism, yes, out, algebras, coprime,
# Nearest to event: amounting, infraclass, cleric, fright, large, insurers, months, premises,
# Nearest to road: outcrops, covington, cassian, mccormick, tombigbee, downer, suburbs, connects,
# Nearest to versions: bundled, scripting, collection, joke, solaris, os, proportione, minicomputers,
# Nearest to egypt: immersed, axumite, delicate, aryabhata, ndez, hellespont, crowd, tanzanian,
# Nearest to assembly: elected, deputies, abject, legislative, representative, redress, federation, mench,
# Nearest to active: exodus, handicap, upc, kevlar, bhra, microscopy, plaintiffs, adopter,
# Nearest to square: outer, cdp, pi, clarinet, riebeeck, congruent, meters, coordinates,
# Nearest to scale: materialistic, ttan, interquartile, nearest, voltages, slant, kaiju, crossfire,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9897 0.0816 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9883 0.0831 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0188 0.0836 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9987 0.0844 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0110 0.0837 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9806 0.0842 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9751 0.0824 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9777 0.0819 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9636 0.0824 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9855 0.0827 sec/batch
# Nearest to also: in, of, denatured, fundamentalists, catalog, rearrange, modeled, other,
# Nearest to about: apostates, annual, fatimid, news, dwarf, assassinations, gobi, anomalous,
# Nearest to the: of, a, as, in, with, on, this, framework,
# Nearest to most: and, variety, ircii, are, barter, dimensions, redesigns, rapid,
# Nearest to eight: four, one, three, zero, five, two, six, nine,
# Nearest to world: copra, planning, sukhothai, rede, maoists, reinterpreting, of, carbondale,
# Nearest to used: commonly, syngas, maintained, use, whimsical, toast, cyanine, macron,
# Nearest to if: cancels, values, value, yes, algebras, intuitionism, coprime, pontificate,
# Nearest to event: cleric, infraclass, amounting, fright, insurers, large, commemoration, premises,
# Nearest to road: outcrops, cassian, mccormick, tombigbee, covington, downer, realtime, london,
# Nearest to versions: bundled, scripting, solaris, gnu, os, collection, minicomputers, proportione,
# Nearest to egypt: axumite, immersed, aryabhata, delicate, hellespont, ndez, wmd, tanzanian,
# Nearest to assembly: elected, deputies, representative, mench, abject, federation, redress, appointing,
# Nearest to active: exodus, upc, handicap, worldwide, kevlar, karine, bhra, adopter,
# Nearest to square: cdp, outer, pi, riebeeck, clarinet, meters, congruent, coordinates,
# Nearest to scale: materialistic, slant, ttan, nearest, interquartile, voltages, kaiju, gillies,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9729 0.0829 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0939 0.0819 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0216 0.0820 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0385 0.0820 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9680 0.0822 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9520 0.0807 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9995 0.0825 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9265 0.0830 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8533 0.0832 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8748 0.0825 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8027 0.0818 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8643 0.0816 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9122 0.0824 sec/batch
# Nearest to also: in, of, such, other, and, as, the, a,
# Nearest to about: news, dwarf, tokoeka, is, apostates, closest, westview, hemp,
# Nearest to the: in, a, of, with, as, an, this, and,
# Nearest to most: some, and, are, has, as, more, large, variety,
# Nearest to eight: one, four, three, two, five, six, zero, nine,
# Nearest to world: shelly, quickest, of, carbondale, achievements, agassi, worldwide, copra,
# Nearest to used: use, commonly, whimsical, syngas, denote, or, toast, colloquial,
# Nearest to if: cancels, yes, values, belongings, then, skel, subseteq, appendage,
# Nearest to event: events, amounting, commemoration, seleucid, observes, fright, humorists, blackpool,
# Nearest to road: tombigbee, tyrol, cassian, outcrops, connects, downer, covington, subjectively,
# Nearest to versions: solaris, available, gnu, bundled, jabber, scripting, phishing, curt,
# Nearest to egypt: immersed, axumite, aryabhata, crowd, capt, uspto, delicate, hellespont,
# Nearest to assembly: elected, federation, mench, hem, substitute, obadiah, constraint, milhaud,
# Nearest to active: representative, karine, present, optative, perfect, ergative, worldwide, mallet,
# Nearest to square: memel, clarinet, congruent, cdp, outer, pi, gaye, misled,
# Nearest to scale: materialistic, scales, harmonic, slant, austere, crossfire, decimal, cielo,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8123 0.0836 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8491 0.0824 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8489 0.0831 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8597 0.0831 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8528 0.0825 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8530 0.0823 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8612 0.0824 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8206 0.0818 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8928 0.0825 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8770 0.0837 sec/batch
# Nearest to also: in, of, other, such, as, and, a, all,
# Nearest to about: dwarf, news, tokoeka, westview, zero, is, apostates, closest,
# Nearest to the: of, in, a, with, as, this, an, and,
# Nearest to most: some, are, and, has, large, variety, also, as,
# Nearest to eight: four, one, three, two, five, zero, six, nine,
# Nearest to world: of, shelly, worldwide, carbondale, quickest, agassi, copra, s,
# Nearest to used: commonly, use, syngas, toast, usage, or, interchangeable, colloquial,
# Nearest to if: cancels, yes, values, algebras, skel, then, subseteq, belongings,
# Nearest to event: events, amounting, observes, commemoration, seleucid, blackpool, fright, humorists,
# Nearest to road: tyrol, tombigbee, outcrops, cassian, parkway, downer, realtime, triples,
# Nearest to versions: solaris, gnu, available, bundled, scripting, jabber, phishing, eurystheus,
# Nearest to egypt: immersed, axumite, crowd, aryabhata, uspto, capt, delicate, hellespont,
# Nearest to assembly: elected, federation, president, mench, deputies, constraint, appoints, substitute,
# Nearest to active: representative, karine, present, perfect, optative, ergative, worldwide, mallet,
# Nearest to square: memel, clarinet, gaye, congruent, pi, zonker, outer, cdp,
# Nearest to scale: scales, materialistic, cielo, stratigraphy, harmonic, syllables, slant, rhodes,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8590 0.0834 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8485 0.0826 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8404 0.0821 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8235 0.0813 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8737 0.0819 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8281 0.0816 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9465 0.0822 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9236 0.0830 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9067 0.0818 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8090 0.0823 sec/batch
# Nearest to also: in, other, such, of, and, a, all, as,
# Nearest to about: news, tokoeka, dwarf, westview, is, closest, zero, at,
# Nearest to the: of, in, a, as, and, with, on, this,
# Nearest to most: and, are, some, has, with, variety, by, more,
# Nearest to eight: one, four, three, two, five, six, zero, seven,
# Nearest to world: of, worldwide, shelly, copra, organising, rede, carbondale, internet,
# Nearest to used: commonly, use, modern, syngas, usage, for, whimsical, toast,
# Nearest to if: cancels, skel, yes, belongings, then, values, gallatin, subseteq,
# Nearest to event: events, amounting, observes, commemoration, blackpool, fright, seleucid, humorists,
# Nearest to road: tyrol, tombigbee, outcrops, downer, cassian, parkway, subjectively, mcduff,
# Nearest to versions: solaris, available, gnu, bundled, phishing, jabber, scripting, eurystheus,
# Nearest to egypt: immersed, axumite, crowd, capt, uspto, delicate, aryabhata, bunsen,
# Nearest to assembly: elected, federation, role, mench, constraint, appoints, deputies, hem,
# Nearest to active: optative, perfect, present, representative, karine, ergative, worldwide, mallet,
# Nearest to square: memel, gaye, clarinet, congruent, cdp, outer, zonker, pi,
# Nearest to scale: materialistic, scales, slant, syllables, austere, stratigraphy, decimal, harmonic,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7899 0.0831 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8690 0.0815 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7649 0.0814 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8572 0.0823 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8505 0.0813 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8526 0.0814 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9052 0.0401 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8480 0.0826 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8637 0.0827 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8361 0.0825 sec/batch
# Nearest to also: in, other, of, as, such, a, all, and,
# Nearest to about: is, news, tokoeka, westview, dwarf, zero, closest, at,
# Nearest to the: in, of, a, with, an, this, on, as,
# Nearest to most: and, are, some, has, as, variety, more, such,
# Nearest to eight: one, four, three, two, five, six, nine, seven,
# Nearest to world: of, worldwide, quickest, copra, shelly, organising, agassi, sukhothai,
# Nearest to used: commonly, use, syngas, usage, whimsical, modern, toast, for,
# Nearest to if: cancels, skel, belongings, yes, then, gallatin, values, polyandry,
# Nearest to event: events, amounting, fright, observes, blackpool, commemoration, seleucid, humorists,
# Nearest to road: tyrol, outcrops, tombigbee, downer, cassian, mcduff, parkway, covington,
# Nearest to versions: solaris, available, gnu, bundled, phishing, scripting, os, jabber,
# Nearest to egypt: immersed, axumite, crowd, delicate, bunsen, aryabhata, capt, uspto,
# Nearest to assembly: elected, federation, constraint, mench, hem, substitute, appease, appoints,
# Nearest to active: representative, karine, optative, present, perfect, worldwide, mallet, ergative,
# Nearest to square: memel, gaye, clarinet, congruent, outer, cdp, zonker, nave,
# Nearest to scale: scales, materialistic, harmonic, syllables, decimal, cielo, stratigraphy, inconsistency,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8197 0.0846 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8043 0.0832 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8224 0.0823 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7638 0.0807 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8382 0.0820 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8163 0.0830 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8755 0.0836 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7668 0.0833 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8242 0.0831 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8126 0.0835 sec/batch
# Nearest to also: in, of, and, such, as, a, other, all,
# Nearest to about: tokoeka, news, dwarf, is, praised, hemp, zero, westview,
# Nearest to the: in, of, a, this, with, and, as, an,
# Nearest to most: and, are, some, has, as, a, more, variety,
# Nearest to eight: four, one, three, two, five, zero, six, seven,
# Nearest to world: worldwide, of, copra, quickest, achievements, germany, sukhothai, shelly,
# Nearest to used: use, commonly, for, modern, usage, or, syngas, whimsical,
# Nearest to if: then, cancels, yes, values, belongings, skel, subseteq, polyandry,
# Nearest to event: events, amounting, observes, seleucid, blackpool, commemoration, fright, humorists,
# Nearest to road: tombigbee, outcrops, tyrol, parkway, roads, downer, cassian, mcduff,
# Nearest to versions: solaris, available, gnu, scripting, bundled, jabber, phishing, ratified,
# Nearest to egypt: immersed, axumite, crowd, delicate, capt, bunsen, uspto, hellespont,
# Nearest to assembly: elected, constraint, federation, mench, appoints, legislative, hem, substitute,
# Nearest to active: karine, present, representative, optative, worldwide, perfect, mallet, ergative,
# Nearest to square: memel, gaye, clarinet, cdp, outer, nave, congruent, pi,
# Nearest to scale: scales, materialistic, harmonic, austere, syllables, decimal, stratigraphy, cielo,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7551 0.0842 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8239 0.0825 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8524 0.0815 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8454 0.0816 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8347 0.0816 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8845 0.0828 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8481 0.0818 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8358 0.0826 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8434 0.0823 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8402 0.0813 sec/batch
# Nearest to also: in, of, such, and, a, other, all, as,
# Nearest to about: tokoeka, is, news, dwarf, hemp, closest, westview, praised,
# Nearest to the: in, of, a, with, as, an, this, is,
# Nearest to most: some, and, are, has, as, a, such, variety,
# Nearest to eight: four, one, three, two, five, zero, nine, six,
# Nearest to world: of, paparizou, shelly, quickest, achievements, worldwide, copra, armigerous,
# Nearest to used: use, commonly, for, or, modern, usage, of, whimsical,
# Nearest to if: cancels, then, skel, belongings, yes, complied, saarland, values,
# Nearest to event: events, amounting, observes, blackpool, seleucid, commemoration, fright, premises,
# Nearest to road: tyrol, outcrops, tombigbee, roads, parkway, connects, cassian, realtime,
# Nearest to versions: solaris, available, gnu, scripting, bundled, phishing, jabber, eidolon,
# Nearest to egypt: immersed, axumite, capt, bunsen, uspto, delicate, crowd, hellespont,
# Nearest to assembly: elected, federation, legislative, president, constraint, hem, appoints, mench,
# Nearest to active: representative, karine, present, perfect, worldwide, optative, ergative, mallet,
# Nearest to square: memel, gaye, pi, clarinet, congruent, cdp, outer, tiananmen,
# Nearest to scale: scales, cielo, materialistic, austere, syllables, decimal, harmonic, stratigraphy,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8853 0.0830 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8216 0.0821 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8203 0.0823 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8331 0.0813 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8623 0.0814 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8451 0.0820 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8047 0.0822 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8291 0.0822 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8230 0.0820 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7896 0.0819 sec/batch
# Nearest to also: in, of, other, such, and, as, a, all,
# Nearest to about: zero, is, tokoeka, westview, news, and, dwarf, estimated,
# Nearest to the: in, of, a, with, as, and, an, this,
# Nearest to most: some, and, are, has, with, as, many, such,
# Nearest to eight: three, one, four, two, five, zero, nine, seven,
# Nearest to world: of, worldwide, germany, s, copra, achievements, internet, shelly,
# Nearest to used: use, commonly, for, or, usage, of, modern, also,
# Nearest to if: then, cancels, skel, only, values, it, belongings, yes,
# Nearest to event: events, amounting, observes, blackpool, commemoration, fright, premises, projector,
# Nearest to road: tyrol, outcrops, tombigbee, downer, cassian, mcduff, realtime, roads,
# Nearest to versions: solaris, available, gnu, bundled, scripting, phishing, jabber, os,
# Nearest to egypt: immersed, axumite, uspto, capt, bunsen, crowd, hellespont, delicate,
# Nearest to assembly: elected, federation, president, constraint, mench, legislative, appease, role,
# Nearest to active: present, karine, representative, perfect, optative, worldwide, ergative, mallet,
# Nearest to square: memel, gaye, clarinet, tiananmen, pi, congruent, cdp, zonker,
# Nearest to scale: scales, materialistic, cielo, stratigraphy, decimal, slant, rhodes, austere,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8739 0.0844 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8239 0.0819 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8853 0.0820 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9274 0.0822 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8857 0.0819 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8451 0.0822 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7850 0.0821 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8355 0.0826 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7320 0.0830 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8798 0.0818 sec/batch
# Nearest to also: in, of, other, such, and, as, a, by,
# Nearest to about: is, tokoeka, news, estimated, westview, at, hemp, closest,
# Nearest to the: of, in, a, as, an, with, and, this,
# Nearest to most: some, and, are, has, with, of, other, by,
# Nearest to eight: one, four, three, two, five, six, seven, nine,
# Nearest to world: of, germany, worldwide, s, shelly, quickest, copra, paparizou,
# Nearest to used: commonly, use, for, or, usage, also, syngas, denote,
# Nearest to if: then, cancels, skel, values, belongings, dq, say, yes,
# Nearest to event: events, amounting, observes, fright, blackpool, commemoration, psa, premises,
# Nearest to road: tyrol, outcrops, tombigbee, mcduff, downer, cassian, fulness, london,
# Nearest to versions: solaris, gnu, available, phishing, latest, eidolon, bundled, scripting,
# Nearest to egypt: immersed, axumite, uspto, capt, bunsen, crowd, delicate, hellespont,
# Nearest to assembly: elected, federation, legislative, constraint, mench, president, executive, unicameral,
# Nearest to active: present, representative, karine, perfect, optative, ergative, worldwide, mallet,
# Nearest to square: memel, clarinet, gaye, tiananmen, pi, cdp, misled, bahasa,
# Nearest to scale: scales, materialistic, austere, stratigraphy, cielo, decimal, syllables, consisted,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8560 0.0842 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8097 0.0825 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
